# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = pd.Series([4, 7, 5, 7, 2, 9, 8])
y = pd.Series([9, 7, 4, 10, 12, 9, 8])

# %%
plt.scatter(x, y)
plt.axvline(x.mean())
plt.axhline(y.mean())
