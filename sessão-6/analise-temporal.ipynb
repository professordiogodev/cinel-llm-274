# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("minhas-vendas.csv")
df.head()
# Out:
#          date product_category  units_sold  revenue customer_region
# 0  2026/03/01      Eletrônicos          12  1200.50           Norte
# 1  2026/03/02        Vestuário          45   890.20             Sul
# 2  2026/03/03      Eletrônicos           8   850.00           Leste
# 3  2026/03/04        Alimentos         120   600.75           Oeste
# 4  2026/03/05        Vestuário          30   600.00           Norte

# %%
df.dtypes
# Out:
# date                    str
# product_category        str
# units_sold            int64
# revenue             float64
# customer_region         str
# dtype: object

# %%
df["date"] = pd.to_datetime(df["date"], format="%Y/%m/%d")

# %%
df.head()
# Out:
#         date product_category  units_sold  revenue customer_region
# 0 2026-03-01      Eletrônicos          12  1200.50           Norte
# 1 2026-03-02        Vestuário          45   890.20             Sul
# 2 2026-03-03      Eletrônicos           8   850.00           Leste
# 3 2026-03-04        Alimentos         120   600.75           Oeste
# 4 2026-03-05        Vestuário          30   600.00           Norte

# %%
df.dtypes
# Out:
# date                datetime64[us]
# product_category               str
# units_sold                   int64
# revenue                    float64
# customer_region                str
# dtype: object
